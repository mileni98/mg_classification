# %% [markdown]
# ## Dataset Analysis

# %%
import os
import pandas as pd

# %% [markdown]
# Read extracted features dataset into a data frame

# %%
data_dir = os.path.join(os.getcwd(), "data", "extracted_features.csv")
data_df = pd.read_csv(data_dir)

# Shape of data frame
print('Data frame dimensions are:', data_df.shape)
# Out:
# Data frame dimensions are: (2734, 128)

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# Drop columns that have only 1 unique value

# %%
drop_columns = []
count = 0

for column in data_df.columns:
    unique_values = data_df[column].nunique()
    if unique_values == 1:
        drop_columns.append(column)
        count += 1

print("There are", count, "columns with unique values.")
print("These columns are:", drop_columns)
# Out:
# There are 13 columns with unique values.
# These columns are: ['diagnostics_Versions_PyRadiomics', 'diagnostics_Versions_Numpy', 'diagnostics_Versions_SimpleITK', 'diagnostics_Versions_PyWavelet', 'diagnostics_Versions_Python', 'diagnostics_Configuration_Settings', 'diagnostics_Configuration_EnabledImageTypes', 'diagnostics_Image-original_Dimensionality', 'diagnostics_Image-original_Spacing', 'diagnostics_Image-original_Size', 'diagnostics_Image-original_Minimum', 'diagnostics_Mask-original_Spacing', 'diagnostics_Mask-original_Size']

# %%
data_df.drop(columns = drop_columns, inplace = True)

# Shape of data frame
print('New data frame dimensions are:', data_df.shape)
# Out:
# New data frame dimensions are: (2734, 115)

# %% [markdown]
# ### Analysis

# %% [markdown]
# Remove all categorical values as they are not important for further numerical analysis

# %%
categorical_feats = data_df.dtypes[data_df.dtypes == "object"].index
categorical_column_names = list(categorical_feats)

print("Number of categorical features:", len(categorical_column_names))
print("Categorical column names:", categorical_column_names)
# Out:
# Number of categorical features: 7
# Categorical column names: ['diagnostics_Image-original_Hash', 'diagnostics_Mask-original_Hash', 'diagnostics_Mask-original_BoundingBox', 'diagnostics_Mask-original_CenterOfMassIndex', 'diagnostics_Mask-original_CenterOfMass', 'name', 'provider']

# %%
df_analysis = data_df.drop(columns = categorical_column_names)

# Drop class column as well
df_analysis.drop(columns = ["class"], inplace = True)

# %% [markdown]
# Split data frame into 2 smaller data frames based on the image class

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

class_0_df = df_analysis[data_df['class'] == 0]
class_1_df = df_analysis[data_df['class'] == 1]

# %%
# Statistical values of columns for first data frame
class_0_df.describe()
# Out:
#        diagnostics_Image-original_Mean  diagnostics_Image-original_Maximum  \
# count                       1367.00000                          1367.00000
# mean                          94.75173                           255.00000
# std                           27.41308                             0.00000
# min                           20.22760                           255.00000
# 25%                           76.12902                           255.00000
# 50%                           93.43042                           255.00000
# 75%                          111.94511                           255.00000
# max                          224.35402                           255.00000
#
#        diagnostics_Mask-original_VoxelNum  \
# count                          1367.00000
# mean                          50523.69276
# std                           56971.95886
# min                               2.00000
# 25%                           10580.00000
# 50%                           30920.00000
# 75%                           69037.00000
# max                          262143.00000
#
#        diagnostics_Mask-original_VolumeNum  original_shape2D_Elongation  \
# count                           1367.00000                   1367.00000
# mean                               1.17630                      0.66297
# std                                0.57045                      0.19125
# min                                1.00000                      0.00000
# 25%                                1.00000                      0.54619
# 50%                                1.00000                      0.68990
# 75%                                1.00000                      0.80404
# max                                8.00000                      1.00000
#
#        original_shape2D_MajorAxisLength  original_shape2D_MaximumDiameter  \
# count                        1367.00000                        1367.00000
# mean                          295.31467                         312.01530
# std                           161.71384                         175.18532
# min                             4.61880                           3.60555
# 25%                           158.52743                         164.50830
# 50%                           280.81359                         294.26689
# 75%                           409.26679                         427.29306
# max                           748.14703                         723.37058
#
#        original_shape2D_MeshSurface  original_shape2D_MinorAxisLength  \
# count                    1367.00000                        1367.00000
# mean                    50523.14082                         190.60980
# std                     56971.98106                         121.92897
# min                         1.00000                           0.00000
# 25%                     10579.50000                          92.72815
# 50%                     30920.00000                         163.86956
# 75%                     69036.25000                         261.85411
# max                    262142.50000                         591.19994
#
#        original_shape2D_Perimeter  ...  \
# count                  1367.00000  ...
# mean                    923.09483  ...
# std                     555.93381  ...
# min                       5.65685  ...
# 25%                     456.71782  ...
# 50%                     846.44069  ...
# 75%                    1272.64527  ...
# max                    4339.16392  ...
#
#        original_glszm_SmallAreaLowGrayLevelEmphasis  \
# count                                    1367.00000
# mean                                        0.03239
# std                                         0.03188
# min                                         0.00745
# 25%                                         0.01839
# 50%                                         0.02527
# 75%                                         0.03731
# max                                         0.62500
#
#        original_glszm_ZoneEntropy  original_glszm_ZonePercentage  \
# count                  1367.00000                     1367.00000
# mean                      5.31181                        0.38721
# std                       0.52912                        0.09348
# min                       0.91830                        0.06507
# 25%                       5.03637                        0.33275
# 50%                       5.37098                        0.38007
# 75%                       5.65310                        0.44122
# max                       6.94020                        1.00000
#
#        original_glszm_ZoneVariance  original_ngtdm_Busyness  \
# count                   1367.00000               1367.00000
# mean                      16.27916                 48.49247
# std                       43.64894                 71.14318
# min                        0.00000                  0.00000
# 25%                        4.35647                 10.56728
# 50%                        7.22535                 24.93010
# 75%                       14.00100                 55.38842
# max                      847.98978                575.79211
#
#        original_ngtdm_Coarseness  original_ngtdm_Complexity  \
# count                 1367.00000                 1367.00000
# mean                  2926.11713                   15.75089
# std                  54034.14899                    4.77580
# min                      0.00004                    0.00000
# 25%                      0.00035                   13.13699
# 50%                      0.00071                   15.55078
# 75%                      0.00175                   18.33090
# max                1000000.00000                   41.25065
#
#        original_ngtdm_Contrast  original_ngtdm_Strength    patient
# count               1367.00000               1367.00000 1367.00000
# mean                   0.03372                  0.06578  965.21287
# std                    0.01439                  0.11986  809.06866
# min                    0.00000                  0.00000    1.00000
# 25%                    0.02307                  0.01558   75.00000
# 50%                    0.03267                  0.03306  692.00000
# 75%                    0.04240                  0.07469 1869.00000
# max                    0.14526                  2.74366 2182.00000
#
# [8 rows x 107 columns]

# %%
# Statistical values of columns for first data frame
class_1_df.describe()
# Out:
#        diagnostics_Image-original_Mean  diagnostics_Image-original_Maximum  \
# count                       1367.00000                          1367.00000
# mean                          83.25425                           254.62692
# std                           31.69520                             9.75016
# min                            0.00000                             0.00000
# 25%                           60.41353                           255.00000
# 50%                           79.69069                           255.00000
# 75%                          100.86866                           255.00000
# max                          248.04543                           255.00000
#
#        diagnostics_Mask-original_VoxelNum  \
# count                          1367.00000
# mean                         261121.00000
# std                               0.00000
# min                          261121.00000
# 25%                          261121.00000
# 50%                          261121.00000
# 75%                          261121.00000
# max                          261121.00000
#
#        diagnostics_Mask-original_VolumeNum  original_shape2D_Elongation  \
# count                           1367.00000                   1367.00000
# mean                               1.00000                      1.00000
# std                                0.00000                      0.00000
# min                                1.00000                      1.00000
# 25%                                1.00000                      1.00000
# 50%                                1.00000                      1.00000
# 75%                                1.00000                      1.00000
# max                                1.00000                      1.00000
#
#        original_shape2D_MajorAxisLength  original_shape2D_MaximumDiameter  \
# count                        1367.00000                        1367.00000
# mean                          590.05085                         721.95637
# std                             0.00000                           0.00000
# min                           590.05085                         721.95637
# 25%                           590.05085                         721.95637
# 50%                           590.05085                         721.95637
# 75%                           590.05085                         721.95637
# max                           590.05085                         721.95637
#
#        original_shape2D_MeshSurface  original_shape2D_MinorAxisLength  \
# count                    1367.00000                        1367.00000
# mean                   261120.50000                         590.05085
# std                         0.00000                           0.00000
# min                    261120.50000                         590.05085
# 25%                    261120.50000                         590.05085
# 50%                    261120.50000                         590.05085
# 75%                    261120.50000                         590.05085
# max                    261120.50000                         590.05085
#
#        original_shape2D_Perimeter  ...  \
# count                  1367.00000  ...
# mean                   2042.82843  ...
# std                       0.00000  ...
# min                    2042.82843  ...
# 25%                    2042.82843  ...
# 50%                    2042.82843  ...
# 75%                    2042.82843  ...
# max                    2042.82843  ...
#
#        original_glszm_SmallAreaLowGrayLevelEmphasis  \
# count                                    1367.00000
# mean                                        0.06628
# std                                         0.03348
# min                                         0.00000
# 25%                                         0.04082
# 50%                                         0.05964
# 75%                                         0.08752
# max                                         0.23189
#
#        original_glszm_ZoneEntropy  original_glszm_ZonePercentage  \
# count                  1367.00000                     1367.00000
# mean                      5.40985                        0.33383
# std                       0.57120                        0.10594
# min                      -0.00000                        0.00196
# 25%                       5.04250                        0.26107
# 50%                       5.44872                        0.32645
# 75%                       5.79627                        0.39544
# max                       7.72474                        0.68178
#
#        original_glszm_ZoneVariance  original_ngtdm_Busyness  \
# count                   1367.00000               1367.00000
# mean                      82.64970                390.67918
# std                     1060.68400                131.25159
# min                        0.00000                  0.00000
# 25%                        6.34600                304.31895
# 50%                       13.70706                388.58358
# 75%                       31.82816                469.67781
# max                    29501.38738                981.50908
#
#        original_ngtdm_Coarseness  original_ngtdm_Complexity  \
# count                 1367.00000                 1367.00000
# mean                  1463.05788                   18.53905
# std                  38235.93517                    5.96445
# min                      0.00003                    0.00000
# 25%                      0.00005                   14.19498
# 50%                      0.00007                   17.79668
# 75%                      0.00010                   22.31549
# max                1000000.00000                   43.67643
#
#        original_ngtdm_Contrast  original_ngtdm_Strength    patient
# count               1367.00000               1367.00000 1367.00000
# mean                   0.02082                  0.00650  965.21287
# std                    0.01303                  0.00928  809.06866
# min                    0.00000                  0.00000    1.00000
# 25%                    0.01044                  0.00392   75.00000
# 50%                    0.01820                  0.00530  692.00000
# 75%                    0.02885                  0.00737 1869.00000
# max                    0.08535                  0.26293 2182.00000
#
# [8 rows x 107 columns]

# %% [markdown]
# Calculate means for every column of both data frames in order to compare them

# %%
df0_mean = class_0_df.describe().loc['mean']
df1_mean = class_1_df.describe().loc['mean']

mean_df = pd.DataFrame({'Column Name': df_analysis.columns, 'mean_0': df0_mean, 'mean_1': df1_mean})
mean_df = mean_df.reset_index(drop=True)

# %%
# Initialize the column with zeros
mean_df['Difference_%'] = 0  

# Calculating absolute differences because there are negative values
condition = mean_df['mean_1'] > mean_df['mean_0']
mean_df.loc[condition, 'Difference_%'] = abs(mean_df['mean_1'] / mean_df['mean_0'] * 100)

condition = mean_df['mean_0'] > mean_df['mean_1']
mean_df.loc[condition, 'Difference_%'] = abs(mean_df['mean_0'] / mean_df['mean_1'] * 100)

# %%
sorted_mean_df = mean_df.sort_values('Difference_%', ascending=False)
sorted_mean_df.head(30)
# Out:
#                                            Column Name      mean_0  \
# 23                         original_firstorder_Minimum    14.12582
# 91        original_glszm_LargeAreaLowGrayLevelEmphasis     2.98475
# 75          original_glrlm_LongRunLowGrayLevelEmphasis     2.99017
# 89                    original_glszm_LargeAreaEmphasis    24.85629
# 73                      original_glrlm_LongRunEmphasis    24.90876
# 105                            original_ngtdm_Strength     0.06578
# 101                            original_ngtdm_Busyness    48.49247
# 27                        original_firstorder_Skewness    -0.09831
# 59                original_gldm_GrayLevelNonUniformity  7338.56317
# 10              original_shape2D_PerimeterSurfaceRatio     0.04931
# 85               original_glszm_GrayLevelNonUniformity  2564.23987
# 69               original_glrlm_GrayLevelNonUniformity  2569.87701
# 56               original_gldm_DependenceNonUniformity 19966.12141
# 7                         original_shape2D_MeshSurface 50523.14082
# 2                   diagnostics_Mask-original_VoxelNum 50523.69276
# 11                       original_shape2D_PixelSurface 50523.69276
# 81                          original_glrlm_RunVariance    16.27916
# 100                        original_glszm_ZoneVariance    16.27916
# 33                          original_glcm_ClusterShade    -7.55791
# 93                original_glszm_SizeZoneNonUniformity  4897.90656
# 78               original_glrlm_RunLengthNonUniformity  4908.67322
# 90       original_glszm_LargeAreaHighGrayLevelEmphasis  1571.91594
# 74         original_glrlm_LongRunHighGrayLevelEmphasis  1575.36407
# 64   original_gldm_LargeDependenceLowGrayLevelEmphasis     0.46028
# 8                     original_shape2D_MinorAxisLength   190.60980
# 65                  original_gldm_LowGrayLevelEmphasis     0.07665
# 13                    original_firstorder_10Percentile    77.70834
# 76              original_glrlm_LowGrayLevelRunEmphasis     0.06471
# 92             original_glszm_LowGrayLevelZoneEmphasis     0.06571
# 63   original_gldm_LargeDependenceHighGrayLevelEmph...   255.97730
#
#           mean_1  Difference_%
# 23       0.01390  101631.57895
# 91     412.89468   13833.47887
# 75     412.89468   13808.40805
# 89     485.77108    1954.31862
# 73     485.77108    1950.20189
# 105      0.00650    1011.61688
# 101    390.67918     805.64922
# 27       0.77773     791.06352
# 59   52882.04248     720.60485
# 10       0.00782     630.27097
# 85   15331.91143     597.91253
# 69   15331.91143     596.60098
# 56  110381.32403     552.84310
# 7   261120.50000     516.83347
# 2   261121.00000     516.82881
# 11  261121.00000     516.82881
# 81      82.64970     507.70247
# 100     82.64970     507.70247
# 33      36.12586     477.98770
# 93   22987.37096     469.33053
# 78   22987.37096     468.30111
# 90    7044.74214     448.16278
# 74    7044.74214     447.18185
# 64       1.57728     342.68017
# 8      590.05085     309.55955
# 65       0.22271     290.54593
# 13      29.88661     260.01053
# 76       0.15467     239.02779
# 92       0.15467     235.38647
# 63     109.32350     234.14664
